# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeZarama/python/blob/main/01MIAR_10_%2BPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="img/viu_logo.png" width="200">
#
# ## 01MIAR - Estructuras de datos, +Pandas
#
# ![logo](img/python_logo.png)
#
# *Ivan Fuertes*

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Operaciones en pandas

# %% [markdown]
# #### Búsqueda

# %%
rand_matrix = np.random.randint(6,size=(2,3))
frame = pd.DataFrame(rand_matrix , columns=list('ABC'))
display(frame)
# Out:
#    A  B  C
# 0  1  4  5
# 1  0  0  1

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False

# %%
# Contar el número de ocurrencias
print(frame.isin([5]).values.sum())
display(frame.isin([5])) #devuelve una mask con valores true si el elemento es 4
type(frame.isin([1]).values) # pandas es una capa alrededor de numpy
# Out:
# 1
#        A      B      C
# 0  False  False   True
# 1  False  False  False
# numpy.ndarray

# %%
# Cuántos valores son >= 4
mask = frame >= 4
print(mask.values.sum())
display(mask)
# Out:
# 2
#        A      B      C
# 0  False   True   True
# 1  False  False  False

# %% [markdown]
# #### Ordenación

# %%
from random import shuffle

rand_matrix = np.random.randint(20,size=(5,4))

indices = list(range(5))
shuffle(indices) # mezcla indices

frame = pd.DataFrame(rand_matrix , columns=list('DACB'), index=indices)
display(frame)
# Out:
#     D   A   C  B
# 0  12   5  13  6
# 3   5  19  17  2
# 2   1  14   7  8
# 1  16  16  17  6
# 4   8  13   4  0

# %%
# ordenar por índice
display(frame.sort_index(ascending=True))
display(frame)
# Out:
#     D   A   C  B
# 0  12   5  13  6
# 1  16  16  17  6
# 2   1  14   7  8
# 3   5  19  17  2
# 4   8  13   4  0
#     D   A   C  B
# 0  12   5  13  6
# 3   5  19  17  2
# 2   1  14   7  8
# 1  16  16  17  6
# 4   8  13   4  0

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=True))
# Out:
#     A  B   C   D
# 0   5  6  13  12
# 3  19  2  17   5
# 2  14  8   7   1
# 1  16  6  17  16
# 4  13  0   4   8

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=False))
# Out:
#     D   A   C  B
# 3   5  19  17  2
# 1  16  16  17  6
# 2   1  14   7  8
# 4   8  13   4  0
# 0  12   5  13  6

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#    B   D   A   C
# 0  6  12   5  13
# 3  2   5  19  17
# 2  8   1  14   7
# 1  6  16  16  17
# 4  0   8  13   4

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#     D   A   C  B
# 3   5  19  17  2
# 1  16  16  17  6
# 2   1  14   7  8
# 4   8  13   4  0
# 0  12   5  13  6

# %% [markdown]
# #### Ranking
# - Construir un ranking de valores

# %%
display(frame)
# Out:
#     D   A   C  B
# 3   5  19  17  2
# 1  16  16  17  6
# 2   1  14   7  8
# 4   8  13   4  0
# 0  12   5  13  6

# %%
display(frame.rank(method='average'))
# Out:
#      D    A    C    B
# 3  2.0  5.0  4.5  2.0
# 1  5.0  4.0  4.5  3.5
# 2  1.0  3.0  2.0  5.0
# 4  3.0  2.0  1.0  1.0
# 0  4.0  1.0  3.0  3.5

# %%
# Imprimir, uno a uno, los valores de la columna 'C' de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 17
# 17
# 13
# 7
# 4

# %% [markdown]
# # Operaciones

# %% [markdown]
# Operaciones matemáticas entre objetos

# %%
matrixA = np.random.randint(100,size=(4,4))
matrixB = np.random.randint(100,size=(4,4))
frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)
display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0   7  50  12   5
# 1  66  40   7  88
# 2  57  72  98  48
# 3  33  98  79  72
#     0   1   2   3
# 0  95  55  24  70
# 1  53  75  66  43
# 2  51  95  79  49
# 3  60  11  11  11

# %%
# a través de métodos u operadores
display(frameA + frameB == frameA.add(frameB))
display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#      0    1    2    3
# 0  102  105   36   75
# 1  119  115   73  131
# 2  108  167  177   97
# 3   93  109   90   83

# %%
display(frameB - frameA == frameB.sub(frameA))
display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0  88   5  12  65
# 1 -13  35  59 -45
# 2  -6  23 -19   1
# 3  27 -87 -68 -61

# %%
# si los frames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100,size=(3,3)))
display(frameA)
display(frameC)
display(frameA + frameC)
# Out:
#     0   1   2   3
# 0   7  50  12   5
# 1  66  40   7  88
# 2  57  72  98  48
# 3  33  98  79  72
#     0   1   2
# 0  58  39  37
# 1  91  12  52
# 2  34  73  29
#        0      1      2   3
# 0   65.0   89.0   49.0 NaN
# 1  157.0   52.0   59.0 NaN
# 2   91.0  145.0  127.0 NaN
# 3    NaN    NaN    NaN NaN

# %%
# se puede especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#        0      1      2     3
# 0   65.0   89.0   49.0   5.0
# 1  157.0   52.0   59.0  88.0
# 2   91.0  145.0  127.0  48.0
# 3   33.0   98.0   79.0  72.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
display(frameD)
frameA - frameD
# Out:
#    0  1
# 0  a  d
# 1  b  f
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      69         _store_test_result(False)
# ---> 70     return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f841e3c1a191> in <cell line: 3>()
#       1 frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
#       2 display(frameD)
# ----> 3 frameA - frameD
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __sub__(self, other)
#     108     @unpack_zerodim_and_defer("__sub__")
#     109     def __sub__(self, other):
# --> 110         return self._arith_method(other, operator.sub)
#     111
#     112     @unpack_zerodim_and_defer("__rsub__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    7585     def _arith_method(self, other, op):
#    7586         if ops.should_reindex_frame_op(self, other, op, 1, 1, None, None):
# -> 7587             return ops.frame_arith_method_with_reindex(self, other, op)
#    7588
#    7589         axis = 1  # only relevant for Series other case
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/__init__.py in frame_arith_method_with_reindex(left, right, op)
#     366     new_left = left.iloc[:, lcols]
#     367     new_right = right.iloc[:, rcols]
# --> 368     result = op(new_left, new_right)
#     369
#     370     # Do the join on the columns instead of using align_method_FRAME
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __sub__(self, other)
#     108     @unpack_zerodim_and_defer("__sub__")
#     109     def __sub__(self, other):
# --> 110         return self._arith_method(other, operator.sub)
#     111
#     112     @unpack_zerodim_and_defer("__rsub__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    7592         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    7593
# -> 7594         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7595         return self._construct_result(new_data)
#    7596
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    7631             # TODO operate_blockwise expects a manager of the same type
#    7632             with np.errstate(all="ignore"):
# -> 7633                 bm = self._mgr.operate_blockwise(
#    7634                     # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7635                     # incompatible type "Union[ArrayManager, BlockManager]"; expected
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in operate_blockwise(self, other, array_op)
#    1587         Apply array_op blockwise with another (aligned) BlockManager.
#    1588         """
# -> 1589         return operate_blockwise(self, other, array_op)
#    1590
#    1591     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/ops.py in operate_blockwise(left, right, array_op)
#      61     res_blks: list[Block] = []
#      62     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 63         res_values = array_op(lvals, rvals)
#      64         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      65             res_values = res_values.reshape(1, -1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     224         # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226         res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     227
#     228     return res_values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     170             # Don't do this for comparisons, as that will handle complex numbers
#     171             #  incorrectly, see GH#32047
# --> 172             result = _masked_arith_op(left, right, op)
#     173         else:
#     174             raise
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     108         # See GH#5284, GH#5035, GH#19448 for historical reference
#     109         if mask.any():
# --> 110             result[mask] = op(xrav[mask], yrav[mask])
#     111
#     112     else:
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %% [markdown]
# Operaciones entre Series y DataFrames

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
df = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(df)

display(type(df.iloc[0]))
# uso común, averiguar la diferencia entre una fila y el resto
display(df - df.iloc[0])
# Por columnas cómo se restaría
display(df.sub(df['A'], axis=0))
# Out:
#    A  B  C  D
# 0  1  5  7  9
# 1  4  5  0  1
# 2  7  3  6  1
# pandas.core.series.Series
#    A  B  C  D
# 0  0  0  0  0
# 1  3  0 -7 -8
# 2  6 -2 -1 -8
#    A  B  C  D
# 0  0  4  6  8
# 1  0  1 -4 -3
# 2  0 -4 -1 -6

# %% [markdown]
# pandas se basa en NumPy, np operadores binarios y unarios son aceptables
#
# | Tipo | Operación | Descripción |
# |:---------|:-----|:-----|
# | Unario | *abs* | Valor absoluto de cada elemento |
# | | *sqrt* | Raíz cuadrada de cada elemento |
# | | *exp* | e^x, siendo x cad elemento |
# | | *log, log10, log2* | Logaritmos en distintas bases de cada elemento |
# | | *sign* | Retorna el signo de cada elemento (-1 para negativo, 0 o 1 para positivo) |
# | | *ceil* | Redondea cada elemento por arriba |
# | | *floor* | Redondea cada elemento por abajo |
# | | *isnan* | Retorna si cada elemento es Nan |
# | | *cos, sin, tan* | Operaciones trigonométricas en cada elemento |
# | | *arccos, arcsin, arctan* | Inversas de operaciones trigonométricas en cada elemento |
# | Binario | *add* | Suma de dos arrays |
# | | *substract* | Resta de dos arrays |
# | | *multiply* | Multiplicación de dos arrays |
# | | *divide* | División de dos arrays |
# | | *maximum, minimum* | Retorna el valor máximo/mínimo de cada pareja de elementos |
# | | *equal, not_equal* | Retorna la comparación (igual o no igual) de cada pareja de elementos |
# | | *greater, greater_equal, less, less_equal* | Retorna la comparación (>, >=, <, <= respectivamente) de cada pareja de elementos |

# %% [markdown]
# Aplicación de funciones a medida con lambda

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min())) # diferencia por columna, por defecto aplica a la columna
# Out:
#    A  B  C  D
# 0  4  3  7  7
# 1  1  5  5  1
# 2  8  6  8  5
# A    7
# B    3
# C    3
# D    6
# dtype: int64

# %%
# diferencia entre min y max por fila (no columna)
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por fila
# Out:
#    A  B  C  D
# 0  6  3  9  4
# 1  1  2  9  6
# 2  8  3  6  6
# 0    6
# 1    8
# 2    5
# dtype: int64

# %% [markdown]
# # Estadística descriptiva
# - Análisis preliminar de los datos
# - Para Series y DataFrame
#
# | Operación | Descripción |
# |:----------|:------------|
# | count | Número de valores no NaN |
# | describe | Conjunto de estadísticas sumarias|
# | min, max | Valores mínimo y máximo |
# | argmin, argmax | Índices posicionales del valor mínimo y máximo |
# | idxmin, idxmax | Índices semánticos del valor mínimo y máximo |
# | sum | Suma de los elementos |
# | mean | Media de los elementos |
# | median | Mediana de los elementos |
# | mad | Desviación absoluta media del valor medio |
# | var | Varianza de los elementos |
# | std | Desviación estándar de los elementos |
# | cumsum | Suma acumulada de los elementos |
# | diff | Diferencia aritmética de los elementos |

# %%
diccionario = { "nombre" : ["Marisa","Laura","Manuel", "Carlos"], "edad" : [34,34,11, 30],
               "puntos" : [98,12,98,np.nan], "genero": ["F", "F", "M", "M"] }
frame = pd.DataFrame(diccionario)
display(frame)
display(frame.describe(include='all')) # datos generales de elementos
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#         nombre       edad     puntos genero
# count        4   4.000000   3.000000      4
# unique       4        NaN        NaN      2
# top     Marisa        NaN        NaN      F
# freq         1        NaN        NaN      2
# mean       NaN  27.250000  69.333333    NaN
# std        NaN  10.996211  49.652123    NaN
# min        NaN  11.000000  12.000000    NaN
# 25%        NaN  25.250000  55.000000    NaN
# 50%        NaN  32.000000  98.000000    NaN
# 75%        NaN  34.000000  98.000000    NaN
# max        NaN  34.000000  98.000000    NaN

# %%
print(type(frame['edad']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# operadores básicos
# print(frame.sum())

display(frame)
print(frame.sum(axis=1, numeric_only=True))
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
# 0    132.0
# 1     46.0
# 2    109.0
# 3     30.0
# dtype: float64

# %%
frame.mean(numeric_only=True)
# Out:
# edad      27.250000
# puntos    69.333333
# dtype: float64

# %%
frame.cumsum()
# Out:
#                     nombre  edad  puntos genero
# 0                   Marisa    34    98.0      F
# 1              MarisaLaura    68   110.0     FF
# 2        MarisaLauraManuel    79   208.0    FFM
# 3  MarisaLauraManuelCarlos   109     NaN   FFMM

# %%
frame.count()
# Out:
# nombre    4
# edad      4
# puntos    3
# genero    4
# dtype: int64

# %%
frame['edad'].std()
# Out:
# 10.996211468804457

# %%
frame['edad'].idxmax()
# Out:
# 0

# %%
frame['puntos'].idxmin()
# Out:
# 1

# %%
# frame con las filas con los valores maximos de una columna
print(frame['puntos'].max())
display(frame[frame['puntos'] == frame['puntos'].max()])
# Out:
# 98.0
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 2  Manuel    11    98.0      M

# %% [markdown]
# ## Agregaciones

# %%
display(frame)
frame.groupby('genero').count()
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#         nombre  edad  puntos
# genero
# F            2     2       2
# M            2     2       1

# %%
display(frame.groupby('genero').mean(numeric_only=True))
# Out:
#         edad  puntos
# genero
# F       34.0    55.0
# M       20.5    98.0

# %%
display(frame.groupby('genero').max())
# Out:
#         nombre  edad  puntos
# genero
# F       Marisa    34    98.0
# M       Manuel    30    98.0

# %%
# funciones de agregación de varias columnas para obtener distintos estadísticos
display(frame.groupby('genero')[['edad', 'puntos']].aggregate(['min', np.median, max]))
# Out:
#        edad            puntos
#         min median max    min median   max
# genero
# F        34   34.0  34   12.0   55.0  98.0
# M        11   20.5  30   98.0   98.0  98.0

# %%
# Filtrado de los datos en el que el conjunto no supera una media determinada
def media(x):
    return x["edad"].mean() > 30

# display(frame)
# display(frame.groupby('genero').count())
display(frame["edad"].mean())
frame.groupby('genero').filter(media)
# Out:
# 27.25
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# pandas incluye métodos para analizar correlaciones
# - Relación matemática entre dos variables (-1 negativamente relacionadas, 1 positivamente relacionadas, 0 sin relación)
# - obj.corr(obj2) --> medida de correlación entre los datos de ambos objetos
# - https://blogs.oracle.com/ai-and-datascience/post/introduction-to-correlation

# %% [markdown]
# ### Ejemplo Fuel efficiency
# - https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
import pandas as pd
path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, delim_whitespace=True, header=None,
            names = ['mpg', 'cilindros', 'desplazamiento','potencia',
            'peso', 'aceleracion', 'año', 'origen', 'nombre'],
            na_values='?')

# %%
display(mpg_data.sample(5))
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleracion  año  \
# 204  32.0          4            85.0      70.0  1990.0         17.0   76
# 228  18.5          6           250.0      98.0  3525.0         19.0   77
# 30   28.0          4           140.0      90.0  2264.0         15.5   71
# 156  16.0          8           400.0     170.0  4668.0         11.5   75
# 307  26.8          6           173.0     115.0  2700.0         12.9   79
#
#      origen                     nombre
# 204       3               datsun b-210
# 228       1               ford granada
# 30        1        chevrolet vega 2300
# 156       1           pontiac catalina
# 307       1  oldsmobile omega brougham

# %%
display(mpg_data.describe(include='all'))
# Out:
#                mpg   cilindros  desplazamiento    potencia         peso  \
# count   398.000000  398.000000      398.000000  392.000000   398.000000
# unique         NaN         NaN             NaN         NaN          NaN
# top            NaN         NaN             NaN         NaN          NaN
# freq           NaN         NaN             NaN         NaN          NaN
# mean     23.514573    5.454774      193.425879  104.469388  2970.424623
# std       7.815984    1.701004      104.269838   38.491160   846.841774
# min       9.000000    3.000000       68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000      104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000      148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000      262.000000  126.000000  3608.000000
# max      46.600000    8.000000      455.000000  230.000000  5140.000000
#
#         aceleracion         año      origen      nombre
# count    398.000000  398.000000  398.000000         398
# unique          NaN         NaN         NaN         305
# top             NaN         NaN         NaN  ford pinto
# freq            NaN         NaN         NaN           6
# mean      15.568090   76.010050    1.572864         NaN
# std        2.757689    3.697627    0.802055         NaN
# min        8.000000   70.000000    1.000000         NaN
# 25%       13.825000   73.000000    1.000000         NaN
# 50%       15.500000   76.000000    1.000000         NaN
# 75%       17.175000   79.000000    2.000000         NaN
# max       24.800000   82.000000    3.000000         NaN

# %%
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mpg             398 non-null    float64
#  1   cilindros       398 non-null    int64
#  2   desplazamiento  398 non-null    float64
#  3   potencia        392 non-null    float64
#  4   peso            398 non-null    float64
#  5   aceleracion     398 non-null    float64
#  6   año             398 non-null    int64
#  7   origen          398 non-null    int64
#  8   nombre          398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %% [markdown]
# ### Correlaciones entre valores

# %%
mpg_data['mpg'].corr(mpg_data['peso']) # + mpg = - peso
# Out:
